# %% [markdown]
# # 01 Data Audit
#
# Initial reproducibility audit using simulated data only. Replace inputs with cleaned real extracts after manual SEDE downloads.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
SIM = ROOT / 'data' / 'simulated'
sorted(p.name for p in SIM.glob('*.csv'))

# %%
tag_week = pd.read_csv(SIM / 'stackoverflow_tag_week.csv')
user_tag_week = pd.read_csv(SIM / 'stackoverflow_user_tag_week.csv')
post_complexity = pd.read_csv(SIM / 'stackoverflow_post_complexity.csv')

audit = pd.DataFrame({
    'table': ['tag_week', 'user_tag_week', 'post_complexity'],
    'rows': [len(tag_week), len(user_tag_week), len(post_complexity)],
    'columns': [tag_week.shape[1], user_tag_week.shape[1], post_complexity.shape[1]],
})
audit

# %%
tag_week.groupby('tag')[['questions', 'answers', 'accepted_answers']].sum()
